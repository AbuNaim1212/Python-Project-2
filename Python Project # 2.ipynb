# %%
#Import Tools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
#Import the data file 
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv', index_col=False)

# %%
#Show the first 10 rows of the import data
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
#Show the last 10 rows of the import data
df.tail(10)
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101756     443842070    140199494            Other  Female  [60-70)      ?
# 101757     443842136    181593374        Caucasian  Female  [70-80)      ?
# 101758     443842340    120975314        Caucasian  Female  [80-90)      ?
# 101759     443842778     86472243        Caucasian    Male  [80-90)      ?
# 101760     443847176     50375628  AfricanAmerican  Female  [60-70)      ?
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
# Checking for any missing values
nan_df = df.isna()
print(nan_df)
# Out:
#         encounter_id  patient_nbr   race  gender    age  weight  \
# 0              False        False  False   False  False   False
# 1              False        False  False   False  False   False
# 2              False        False  False   False  False   False
# 3              False        False  False   False  False   False
# 4              False        False  False   False  False   False
# ...              ...          ...    ...     ...    ...     ...
# 101761         False        False  False   False  False   False
# 101762         False        False  False   False  False   False
# 101763         False        False  False   False  False   False
# 101764         False        False  False   False  False   False
# 101765         False        False  False   False  False   False
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   False                     False                False
# ...

# %%
#Counting Total Columns & Rows
df.shape
# Out:
# (101766, 50)

# %%
#Statistics
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
#Checking Columns legends
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
#Sorting by Gender
#determine gender types
df.groupby(['gender'])['gender'].count().sort_values(ascending = False)
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
#Sorting by Race
df.groupby(['race'])['race'].count().sort_values(ascending = False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %%
#Data Cleaning# Lebel '?' as 'unknown'
df.loc[df['race'] == '?', 'race'] = 'unknown'
df.groupby(['race'])['race'].count().sort_values(ascending = False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# unknown             2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %%
#Creating new data set
df1 = df[['race', 'gender', 'number_diagnoses']]
print(df1)
# Out:
#                    race  gender  number_diagnoses
# 0             Caucasian  Female                 1
# 1             Caucasian  Female                 9
# 2       AfricanAmerican  Female                 6
# 3             Caucasian    Male                 7
# 4             Caucasian    Male                 5
# ...                 ...     ...               ...
# 101761  AfricanAmerican    Male                 9
# 101762  AfricanAmerican  Female                 9
# 101763        Caucasian    Male                13
# 101764        Caucasian  Female                 9
# 101765        Caucasian    Male                 9
#
# [101766 rows x 3 columns]

# %%
# Data set by Gender
df2=df1[['gender', 'number_diagnoses']]
print(df2)
# Out:
#         gender  number_diagnoses
# 0       Female                 1
# 1       Female                 9
# 2       Female                 6
# 3         Male                 7
# 4         Male                 5
# ...        ...               ...
# 101761    Male                 9
# 101762  Female                 9
# 101763    Male                13
# 101764  Female                 9
# 101765    Male                 9
#
# [101766 rows x 2 columns]

# %%
#Visualization by Gender
df2.groupby(df['gender']).count().plot(kind='bar', title = 'Chart-1')
# Out:
# <Axes: title={'center': 'Chart-1'}, xlabel='gender'>

# %%
# Data set by Race
df3=df1[['race', 'number_diagnoses']]
print(df3)
# Out:
#                    race  number_diagnoses
# 0             Caucasian                 1
# 1             Caucasian                 9
# 2       AfricanAmerican                 6
# 3             Caucasian                 7
# 4             Caucasian                 5
# ...                 ...               ...
# 101761  AfricanAmerican                 9
# 101762  AfricanAmerican                 9
# 101763        Caucasian                13
# 101764        Caucasian                 9
# 101765        Caucasian                 9
#
# [101766 rows x 2 columns]

# %%
#Visualization by Race
df3.groupby(df['race']).count().plot(kind='bar', title = 'Chart-2')
# Out:
# <Axes: title={'center': 'Chart-2'}, xlabel='race'>

# %%
#Findings: According to 'Chat-1' Female gender has higher 'Diabetes' diagnoses number and 'Char-2' Caucasian race has higher 'Diabetes' diagnoses number.

# %%
#Seaborn
import seaborn as sns

# %%
sns.barplot(x='gender', y='number_diagnoses', data=df2)
# Out:
# <Axes: xlabel='gender', ylabel='number_diagnoses'>

# %%
sns.barplot(x='race', y='number_diagnoses', data=df3)
# Out:
# <Axes: xlabel='race', ylabel='number_diagnoses'>

# %%
df4 = df.groupby (['diag_1','race']).agg({'encounter_id':'count','num_lab_procedures':'mean','num_medications':'mean','gender':'first'})
print(df4)
# Out:
#                         encounter_id  num_lab_procedures  num_medications  \
# diag_1 race
# 10     Other                       1               49.00        32.000000
# 11     AfricanAmerican             3               53.00        21.333333
#        Asian                       1               55.00        13.000000
#        Caucasian                   2               51.50        21.500000
#        Hispanic                    3               62.00        17.000000
# ...                              ...                 ...              ...
# V66    Other                       1               34.00         5.000000
# V67    Caucasian                   1               11.00        12.000000
# V70    Caucasian                   1               27.00         9.000000
# V71    AfricanAmerican             1               44.00        10.000000
#        Caucasian                   8               28.25         9.125000
#
#                         gender
# diag_1 race
# ...

# %%
sns.jointplot(x='num_lab_procedures', y='num_medications', data=df4, kind='hex')

# %%
sns.pairplot(df4, hue='gender')
# Out:
# C:\Users\ornob\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
